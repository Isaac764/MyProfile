# %% [markdown]
# <a href="https://colab.research.google.com/github/Isaac764/MyProfile/blob/main/autores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cidades = ['Maringá', 'Tabira', 'Uberlândia', 'Salvador','Fortaleza']
populacao =[403.063,120.904,699.097, 2.886698,2.686612]

populacao_cidades =dict(zip(cidades,populacao))

type(populacao_cidades)

populacao_cidades['Uberlândia']

'Maringá' in populacao_cidades

populacao_cidades['Vitória'] = 365.855

del populacao_cidades['Fortaleza']

populacao_cidades
# Out:
# {'Maringá': 403.063,
#  'Tabira': 120.904,
#  'Uberlândia': 699.097,
#  'Salvador': 2.886698,
#  'Vitória': 365.855}

# %%
import pandas as pd

Autor = ['Sun Tzu', 'Fernando Pessoa', 'Thomas Mann', 'Joao Guilherme Rosa']

Livro = ['A Arte da Guerra', 'Poesias Selecionadas', 'A montanha Mágica', 'Primeiras Estórias']

Ano = [200, 2004, 2015, 2017]

dados = {
    'Autor': Autor,
    'Livro': Livro,
    'Ano': Ano
}
autores = pd.DataFrame(dados)
type(autores)

df = pd.DataFrame(autores)
print(df)

df.to_csv("autores.csv")
autores = pd.read_csv('autores.csv', index_col=0)
autores
# Out:
#                  Autor                 Livro   Ano
# 0              Sun Tzu      A Arte da Guerra   200
# 1      Fernando Pessoa  Poesias Selecionadas  2004
# 2          Thomas Mann     A montanha Mágica  2015
# 3  Joao Guilherme Rosa    Primeiras Estórias  2017
#                  Autor                 Livro   Ano
# 0              Sun Tzu      A Arte da Guerra   200
# 1      Fernando Pessoa  Poesias Selecionadas  2004
# 2          Thomas Mann     A montanha Mágica  2015
# 3  Joao Guilherme Rosa    Primeiras Estórias  2017
